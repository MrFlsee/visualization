# %%
import dask.dataframe as dd

# %%
# %time df = dd.read_csv('data.csv',
dtype={
    'Active.Std': 'float64',
    'Bwd.IAT.Max': 'float64',
    'Flow.IAT.Max': 'float64',
    'Fwd.IAT.Max': 'float64',
    'Fwd.IAT.Min': 'float64',
    'Fwd.IAT.Total': 'float64'})
# Out:
#   File "<ipython-input-20-7e8d2875a921>", line 8
#     'Fwd.IAT.Total': 'float64'})
#                                ^
# SyntaxError: invalid syntax

# %%
df.head(5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-a29405eb924b> in <module>
# ----> 1 df.head(5)
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/dask/dataframe/core.py in head(self, n, npartitions, compute)
#    1003             Whether to compute the result, default is True.
#    1004         """
# -> 1005         return self._head(n=n, npartitions=npartitions, compute=compute, safe=True)
#    1006
#    1007     def _head(self, n, npartitions, compute, safe):
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/dask/dataframe/core.py in _head(self, n, npartitions, compute, safe)
#    1036
#    1037         if compute:
# -> 1038             result = result.compute()
#    1039         return result
#    1040
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/dask/base.py in compute(self, **kwargs)
# ...
